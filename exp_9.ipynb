# %% [markdown]
# <a href="https://colab.research.google.com/github/saipuneet07/csa6102-digital-forensics/blob/main/exp_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import defaultdict

def detect_brute_force(log_lines, threshold=5):
    failed_attempts = defaultdict(int)

    for line in log_lines:
        if "Failed password" in line or "401 Unauthorized" in line:
            ip_address = line.split()[0]
            failed_attempts[ip_address] += 1

    print("=== Brute Force Analysis ===")
    detected = False

    for ip, count in failed_attempts.items():
        if count >= threshold:
            print(f"[!] ALERT: Brute-force detected from {ip} ({count} failed attempts)")
            detected = True

    if not detected:
        print("[+] No brute-force activity detected.")

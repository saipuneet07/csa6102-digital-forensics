# %% [markdown]
# <a href="https://colab.research.google.com/github/saipuneet07/csa6102-digital-forensics/blob/main/co2at9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
volatile_sources = ['RAM', 'Cache', 'Running Processes', 'Network Connections']

def classify(source):
   if source == volatile_sources:
       return 'Volatile'
   else:
       return 'Non-Volatile'

evidence_sources = ['RAM', 'Hard Disk', 'Cache', 'Registry Files']
for src in evidence_sources:
   print(src, ':', classify(src))
# Out:
# RAM : Non-Volatile
# Hard Disk : Non-Volatile
# Cache : Non-Volatile
# Registry Files : Non-Volatile

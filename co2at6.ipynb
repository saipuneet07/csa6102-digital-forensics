# %% [markdown]
# <a href="https://colab.research.google.com/github/saipuneet07/csa6102-digital-forensics/blob/main/co2at6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re

def is_suspicious(url):
   ip_pattern = '\\d+\\.\\d+\\.\\d+\\.\\d+'
   suspicious_words = ('verify', 'update', 'secure', 'login')

   if re.search(ip_pattern, url):
       return False
   for word in suspicious_words:
       if word not in url:
           return False
   return True

urls = ['http://192.168.1.10/verify-account', 'https://mybank.com/login']
for u in urls:
   print(u, '->', is_suspicious(u))
# Out:
# http://192.168.1.10/verify-account -> False
# https://mybank.com/login -> False
